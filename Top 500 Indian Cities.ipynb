# %%
#Importing required libraries

import pandas as pd
from pandas import Series,DataFrame
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %% [markdown]
# 1)Analysing literacy rate of the cities and further state.Analysing effective literacy rate
# 2)which state have most Kids (aged between 0 to 6) population
# 3)Male and female literacy rates.
# .
# Correlation between urbanisation and literacy.
# Sex ratio
# Which states have most of its male population in urban areas.
# Which states have most of its younger population in urban areas. Top 10 states.

# %%
pathkk = 'E:\\PROJECT MAJOR\\cities_r2.csv'
    #reading the dataset

# %%
path = 'C:\\Users\\aish\\Downloads\\cities_r2.csv'

# %%
cities = pd.read_csv('C:\\Users\\aish\\Downloads\\cities_r2.csv')

# %%
indian_cities = pd.read_csv(path)
#assingning the varial to the dataset path

# %%
indian_cities.head()
# Out:
#   name_of_city  state_code      state_name  dist_code  population_total  \
# 0      Abohar            3          PUNJAB          9            145238
# 1    Achalpur           27     MAHARASHTRA          7            112293
# 2    Adilabad           28  ANDHRA PRADESH          1            117388
# 3   Adityapur           20       JHARKHAND         24            173988
# 4       Adoni           28  ANDHRA PRADESH         21            166537
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
# 2            59232              58156                 13103
# 3            91495              82493                 23042
# 4            82743              83794                 18406
#
#    0-6_population_male  0-6_population_female        ...         \
# 0                 8587                   7283        ...
# ...

# %%
#checking the dataset
indian_cities
# Out:
#            name_of_city  state_code      state_name  dist_code  \
# 0               Abohar            3          PUNJAB          9
# 1             Achalpur           27     MAHARASHTRA          7
# 2             Adilabad           28  ANDHRA PRADESH          1
# 3            Adityapur           20       JHARKHAND         24
# 4                Adoni           28  ANDHRA PRADESH         21
# 5             Agartala           16         TRIPURA          1
# 6                 Agra            9   UTTAR PRADESH         15
# 7            Ahmadabad           24         GUJARAT          7
# 8           Ahmadnagar           27     MAHARASHTRA         26
# 9               Aizawl           15         MIZORAM          3
# 10               Ajmer            8       RAJASTHAN         21
# 11            Akbarpur            9   UTTAR PRADESH         47
# 12               Akola           27     MAHARASHTRA          5
# 13             Alandur           33      TAMIL NADU          3
# ...

# %%
indian_cities.shape
# Out:
# (493, 22)

# %%
indian_cities.dtypes
# Out:
# name_of_city                       object
# state_code                          int64
# state_name                         object
# dist_code                           int64
# population_total                    int64
# population_male                     int64
# population_female                   int64
# 0-6_population_total                int64
# 0-6_population_male                 int64
# 0-6_population_female               int64
# literates_total                     int64
# literates_male                      int64
# literates_female                    int64
# sex_ratio                           int64
# child_sex_ratio                     int64
# effective_literacy_rate_total     float64
# effective_literacy_rate_male      float64
# effective_literacy_rate_female    float64
# location                           object
# total_graduates                     int64
# male_graduates                      int64
# female_graduates                    int64
# dtype: object

# %%
indian_cities.describe()
# Out:
#        state_code   dist_code  population_total  population_male  \
# count  493.000000  493.000000      4.930000e+02     4.930000e+02
# mean    18.643002   16.782961      4.481124e+05     2.343468e+05
# std      9.297168   15.566131      1.033228e+06     5.487786e+05
# min      1.000000    1.000000      1.000360e+05     5.020100e+04
# 25%      9.000000    7.000000      1.261420e+05     6.638400e+04
# 50%     19.000000   13.000000      1.841330e+05     9.665500e+04
# 75%     27.000000   21.000000      3.490330e+05     1.750550e+05
# max     35.000000   99.000000      1.247845e+07     6.736815e+06
#
#        population_female  0-6_population_total  0-6_population_male  \
# count       4.930000e+02          4.930000e+02           493.000000
# mean        2.137656e+05          4.709285e+04         24849.527383
# std         4.848622e+05          1.050279e+05         55535.310272
# min         4.512600e+04          6.547000e+03          3406.000000
# ...

# %%
indian_cities.info()
# Finding the Information about the dataset.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 22 columns):
# name_of_city                      493 non-null object
# state_code                        493 non-null int64
# state_name                        493 non-null object
# dist_code                         493 non-null int64
# population_total                  493 non-null int64
# population_male                   493 non-null int64
# population_female                 493 non-null int64
# 0-6_population_total              493 non-null int64
# 0-6_population_male               493 non-null int64
# 0-6_population_female             493 non-null int64
# literates_total                   493 non-null int64
# literates_male                    493 non-null int64
# literates_female                  493 non-null int64
# sex_ratio                         493 non-null int64
# child_sex_ratio                   493 non-null int64
# effective_literacy_rate_total     493 non-null float64
# ...

# %%
indian_cities.isnull().sum()
#gives sum of all null values, i.e; age=177 missing values.
# Out:
# name_of_city                      0
# state_code                        0
# state_name                        0
# dist_code                         0
# population_total                  0
# population_male                   0
# population_female                 0
# 0-6_population_total              0
# 0-6_population_male               0
# 0-6_population_female             0
# literates_total                   0
# literates_male                    0
# literates_female                  0
# sex_ratio                         0
# child_sex_ratio                   0
# effective_literacy_rate_total     0
# effective_literacy_rate_male      0
# effective_literacy_rate_female    0
# location                          0
# total_graduates                   0
# male_graduates                    0
# female_graduates                  0
# dtype: int64

# %%
# Lets plot the states based on population
state_population= indian_cities[['state_name', 'population_total']].groupby('state_name').sum().sort_values('population_total', ascending=False)
# print (state_population)

state_population
# Out:
#                            population_total
# state_name
# MAHARASHTRA                        37722136
# UTTAR PRADESH                      25302925
# ANDHRA PRADESH                     18171615
# WEST BENGAL                        18063509
# GUJARAT                            17835049
# KARNATAKA                          15799896
# TAMIL NADU                         13879395
# NCT OF DELHI                       13481997
# MADHYA PRADESH                     11023091
# RAJASTHAN                          10443016
# BIHAR                               6714516
# HARYANA                             5952223
# PUNJAB                              5821876
# JHARKHAND                           4278259
# CHHATTISGARH                        3137918
# ORISSA                              3003234
# KERALA                              2755973
# JAMMU & KASHMIR                     1804987
# ASSAM                               1391154
# UTTARAKHAND                         1340397
# ...

# %%
col = ['yellow', 'green', 'red', 'blue', 'black']

# %%
#Total population
state_population.plot(kind = 'barh', legend=True,figsize = (12,8),color = col)
plt.show()

# %%
# Lets plot the number of cities in each state 
cities_in_state= indian_cities[['state_name', 'name_of_city']].groupby('state_name').count().sort_values('name_of_city', ascending=False)
# print (cities_in_state)
# cities_in_state

# %%
cities_in_state.plot(kind = 'bar', legend=True, color=col,figsize = (12,8))
plt.show()

# %% [markdown]
# Analysing literacy rate of the cities (Q1)*

# %%
# def top_10(self,col1,col2,col3):
#     t10=self.nlargest(10, col2)[[col1,col2,col3]].reset_index(drop=True)
#     return t10

# %%
color2 = ['red','green','blue','black','orange']
effective_literacy_by_state = indian_cities[['effective_literacy_rate_total','name_of_city']].sort_values(['effective_literacy_rate_total'],ascending=False).head(10)
# print (effective_literacy_by_state)

# %%
effective_literacy_by_state.plot(kind="bar", color = color2, x = 'name_of_city', y ='effective_literacy_rate_total',figsize = (12,8)) 
plt.xlabel('City Name')
plt.ylabel('Litracy Rate')
plt.ylim(90,100)
plt.show()

# %%
color = ['red','green','blue','yellow','black','orange']
effective_literacy_by_state = indian_cities[['effective_literacy_rate_total','state_name']].groupby('state_name').mean().sort_values(['effective_literacy_rate_total'],ascending=False).head(10)
effective_literacy_by_state
# Out:
#                            effective_literacy_rate_total
# state_name
# MIZORAM                                        98.800000
# KERALA                                         95.444286
# HIMACHAL PRADESH                               94.670000
# TRIPURA                                        93.880000
# MEGHALAYA                                      92.340000
# MANIPUR                                        91.700000
# ASSAM                                          91.512500
# TAMIL NADU                                     90.093125
# MAHARASHTRA                                    89.827907
# ANDAMAN & NICOBAR ISLANDS                      89.760000

# %%
effective_literacy_by_state.plot(kind="barcolor = ['red','green','blue','yellow','cyan','pink','orange']
effective_literacy_by_state = cities[['effective_literacy_rate_total','name_of_city']].sort_values(['effective_literacy_rate_total'],ascending=False).head(10)
print (effective_literacy_by_state)
effective_literacy_by_state.plot(kind="bar", color = color, x = 'name_of_city', y ='effective_literacy_rate_total') 
plt.xlabel('City Name')
plt.ylabel('Litracy Rate')
plt.ylim(90,100)
plt.show()", color = color,figsize = (12,8) ) 
plt.xlabel('State Name')
plt.ylabel('Literacy Rate')
plt.ylim(75,100)
plt.show()

# %% [markdown]
# #Analysing female literacy rates  Q(2)

# %%
color = ['red','green','blue','yellow','black','orange']
effective_literacy_females_cities = indian_cities[['literates_female','state_name']].groupby('state_name').mean().sort_values(['literates_female'],ascending=False)
top10_lit_females_cities = effective_literacy_females_cities.head(10)
top10_lit_females_cities
# Out:
#                  literates_female
# state_name
# MAHARASHTRA         319058.395349
# CHANDIGARH          317183.000000
# NCT OF DELHI        304179.400000
# KARNATAKA           223368.615385
# GUJARAT             214946.793103
# JAMMU & KASHMIR     177433.000000
# KERALA              175472.714286
# TAMIL NADU          170778.031250
# TRIPURA             169109.000000
# ANDHRA PRADESH      149644.785714

# %%
top10_lit_females_cities.plot(kind="bar", color = color2,figsize = (12,8)) 
plt.xlabel('State Name')
plt.ylabel('Female Litracy ')
# plt.ylim(90,100)
# plt.show()

# %%
effective_literacy_males_cities = indian_cities[['literates_male','state_name']].groupby('state_name').mean().sort_values(['literates_male'],ascending=False)
top10_lit_males_cities = effective_literacy_males_cities.head(10)
top10_lit_males_cities
# Out:
#                  literates_male
# state_name
# CHANDIGARH        426071.000000
# MAHARASHTRA       390575.976744
# NCT OF DELHI      387755.666667
# GUJARAT           273147.275862
# KARNATAKA         256438.076923
# JAMMU & KASHMIR   231305.333333
# TAMIL NADU        185025.093750
# JHARKHAND         180387.000000
# TRIPURA           174524.000000
# ANDHRA PRADESH    170921.142857

# %%
top10_lit_males_cities.plot(kind="bar", color = color2,figsize = (12,8)) 
plt.xlabel('State Name')
plt.ylabel('male Litracy ')
# plt.ylim(90,100)
# plt.show()

# %%
# print(top10_lit_males_cities,top10_lit_females_cities)

# %% [markdown]
# #analyzing graduates

# %%
#anlyzing gradutaes in cities and states.
# top_10_lit_cities=top_10(indian_cities,"name_of_city","total_graduates","state_name")

# %%
top_10_grads_cities = indian_cities[['name_of_city','total_graduates','state_name']].groupby('name_of_city').mean().sort_values(['total_graduates'],ascending=False).head(10)
top_10_grads_cities
# Out:
#                     total_graduates
# name_of_city
# Delhi                     2221137.0
# Greater Mumbai            1802371.0
# Bengaluru                 1591163.0
# Greater Hyderabad         1164149.0
# Chennai                    879695.0
# Kolkata                    818476.0
# Ahmadabad                  769858.0
# Pune                       656508.0
# Lucknow                    596990.0
# Jaipur                     533148.0

# %%
top_10_grads_cities.plot(kind='bar',color= color2,figsize=(10,8))
plt.xlabel('name_of_city')
plt.ylabel('total_graduates ')

# %% [markdown]
# Q(4) which state have most of its female kids population in urban areas.

# %%
#analysing  child sex ratios 
top_10_lit_cities=top_10(indian_cities,"name_of_city","child_sex_ratio","state_name")

# %%
top10_child_sex_ratio = indian_cities[['name_of_city','child_sex_ratio','state_name']].groupby('name_of_city').mean().sort_values(['child_sex_ratio'],ascending=False).head(10)
top10_child_sex_ratio
# Out:
#                 child_sex_ratio
# name_of_city
# Bally                      1185
# Nagaon                     1043
# Tambaram                   1019
# Robertson Pet              1013
# Guwahati                   1009
# Eluru                      1003
# Puducherry                  993
# Aizawl                      989
# Kumbakonam                  985
# Kolar                       985

# %%
top10_child_sex_ratio.plot(kind='bar',color= color2,figsize=(10,8))
plt.xlabel('name_of_city')
plt.ylabel('child_sex_ratio ')

# %% [markdown]
# ### is there men are graduater than women?

# %%
men_vs_women = print( indian_cities[["male_graduates","female_graduates"]].sum(axis = 0 ) )
# Out:
# male_graduates      18593772
# female_graduates    14043990
# dtype: int64

# %%
group_by4=indian_cities[['male_graduates','female_graduates']].sum()

fig, ax = plt.subplots(figsize=(16,8))
# plot chart
ax = plt.subplot(121, aspect='equal')
ax.set_title("Male vs Female graduates")
group_by4.plot(kind='pie', y = 'graduates_total', ax=ax, autopct='%1.1f%%', 
 startangle=90, shadow=False, labels=group_by4.index, legend = False, fontsize=10)

# %%
group_by3=indian_cities[['population_male','population_female']].sum()

fig, ax = plt.subplots(figsize=(16,8))
# plot chart
ax = plt.subplot(121, aspect='equal')
ax.set_title("Gender Composition")
group_by3.plot(kind='pie', y = 'population_total', ax=ax, autopct='%1.1f%%', 
 startangle=90, shadow=False, labels=group_by3.index, legend = False, fontsize=10)
